# %% [markdown]
# # Customer Segmentation Using Clustering (Python)

# %% [markdown]
# # IMPORT LIBARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import seaborn as sns

# %% [markdown]
# # LOAD DATASET

# %%
data = pd.read_csv(r"C:\Users\vinee\Downloads\Zaalima Python Project\tele.csv")
data
# Out:
#      CustomerID  Age  Gender    ContractType  MonthlyCharges   TotalSpent  \
# 0             1   56    Male        One Year       96.028982  1249.110874
# 1             2   69  Female        Two Year       33.710971  1570.074519
# 2             3   46    Male        Two Year       73.531013  1790.270343
# 3             4   32  Female        One Year       41.520187   492.452904
# 4             5   60    Male        Two Year       21.212077   594.571244
# ..          ...  ...     ...             ...             ...          ...
# 995         996   37    Male  Month-to-Month       34.080295  1054.704236
# 996         997   41    Male        One Year       82.241364  1664.320414
# 997         998   22    Male        One Year       98.132186  1156.592237
# 998         999   51    Male        Two Year       77.829840   696.748306
# 999        1000   23  Female  Month-to-Month       34.696271  1227.952098
#
#      DevicesConnected  SupportCalls  Churn
# 0                   4             5      0
# 1                   1             7      0
# 2                   4             9      1
# 3                   2             0      1
# 4                   2             3      0
# ..                ...           ...    ...
# 995                 1             9      1
# 996                 3             1      0
# 997                 5             3      1
# 998                 5             5      1
# 999                 4             4      0
#
# [1000 rows x 9 columns]

# %%
data.head()
# Out:
#    CustomerID  Age  Gender ContractType  MonthlyCharges   TotalSpent  \
# 0           1   56    Male     One Year       96.028982  1249.110874
# 1           2   69  Female     Two Year       33.710971  1570.074519
# 2           3   46    Male     Two Year       73.531013  1790.270343
# 3           4   32  Female     One Year       41.520187   492.452904
# 4           5   60    Male     Two Year       21.212077   594.571244
#
#    DevicesConnected  SupportCalls  Churn
# 0                 4             5      0
# 1                 1             7      0
# 2                 4             9      1
# 3                 2             0      1
# 4                 2             3      0

# %% [markdown]
# # DROP UNWANTED COLUMNS

# %%
data = data.drop(["CustomerID", "Churn"], axis=1)
data
# Out:
#      Age  Gender    ContractType  MonthlyCharges   TotalSpent  \
# 0     56    Male        One Year       96.028982  1249.110874
# 1     69  Female        Two Year       33.710971  1570.074519
# 2     46    Male        Two Year       73.531013  1790.270343
# 3     32  Female        One Year       41.520187   492.452904
# 4     60    Male        Two Year       21.212077   594.571244
# ..   ...     ...             ...             ...          ...
# 995   37    Male  Month-to-Month       34.080295  1054.704236
# 996   41    Male        One Year       82.241364  1664.320414
# 997   22    Male        One Year       98.132186  1156.592237
# 998   51    Male        Two Year       77.829840   696.748306
# 999   23  Female  Month-to-Month       34.696271  1227.952098
#
#      DevicesConnected  SupportCalls
# 0                   4             5
# 1                   1             7
# 2                   4             9
# 3                   2             0
# 4                   2             3
# ..                ...           ...
# 995                 1             9
# 996                 3             1
# 997                 5             3
# 998                 5             5
# 999                 4             4
#
# [1000 rows x 7 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
num_cols = ['Age','MonthlyCharges','TotalSpent','DevicesConnected','SupportCalls']
num_cols = [c for c in num_cols if c in data.columns]
data[num_cols].hist(bins=30, figsize=(12,6))
plt.tight_layout(); plt.show()

# %%
plt.figure(figsize=(12,6))
for i,c in enumerate(num_cols):
    plt.subplot(1,len(num_cols), i+1)
    sns.boxplot(y=data[c])
    plt.title(c)
plt.tight_layout(); plt.show()

# %%
if len(num_cols) >= 2:
    sns.pairplot(data[num_cols].sample(frac=0.3, random_state=42))
    plt.show()

# %%
cat_cols = [c for c in ['Gender','ContractType'] if c in data.columns]
for c in cat_cols:
    plt.figure(figsize=(6,3))
    sns.countplot(data=data, x=c, order=data[c].value_counts().index)
    plt.title(c); plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# # HANDLING MISSING VALUES

# %%
data.isnull().sum()
# Out:
# Age                 0
# Gender              0
# ContractType        0
# MonthlyCharges      0
# TotalSpent          0
# DevicesConnected    0
# SupportCalls        0
# dtype: int64

# %%
data = data.replace(" ", np.nan)
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Gender            1000 non-null   object
#  2   ContractType      1000 non-null   object
#  3   MonthlyCharges    1000 non-null   float64
#  4   TotalSpent        1000 non-null   float64
#  5   DevicesConnected  1000 non-null   int64
#  6   SupportCalls      1000 non-null   int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %% [markdown]
# # ENCODE CATEGORICAL COLUMNS

# %%
cat_cols = ["Gender", "ContractType"]

le = LabelEncoder()

for col in cat_cols:
    data[col] = le.fit_transform(data[col])

# %%
data
# Out:
#      Age  Gender  ContractType  MonthlyCharges   TotalSpent  DevicesConnected  \
# 0     56       1             1       96.028982  1249.110874                 4
# 1     69       0             2       33.710971  1570.074519                 1
# 2     46       1             2       73.531013  1790.270343                 4
# 3     32       0             1       41.520187   492.452904                 2
# 4     60       1             2       21.212077   594.571244                 2
# ..   ...     ...           ...             ...          ...               ...
# 995   37       1             0       34.080295  1054.704236                 1
# 996   41       1             1       82.241364  1664.320414                 3
# 997   22       1             1       98.132186  1156.592237                 5
# 998   51       1             2       77.829840   696.748306                 5
# 999   23       0             0       34.696271  1227.952098                 4
#
#      SupportCalls
# 0               5
# 1               7
# 2               9
# 3               0
# 4               3
# ..            ...
# 995             9
# 996             1
# 997             3
# 998             5
# 999             4
#
# [1000 rows x 7 columns]

# %% [markdown]
# # SCALE NUMERICAL COLUMNS

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(data)

# %% [markdown]
# # Elbow Method (Find Optimal K)

# %%
inertia = []

K = range(2, 10)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(K, inertia,marker='o')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.title("Elbow Method")
plt.show()

# %% [markdown]
# # SILHOUETTE SCORE

# %%
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k)
    labels = kmeans.fit_predict(df_scaled)
    score = silhouette_score(df_scaled, labels)
    print(f"K={k}, Silhouette Score={score}")
# Out:
# K=2, Silhouette Score=0.1072855966373292
# K=3, Silhouette Score=0.12158649758139364
# K=4, Silhouette Score=0.12032988963434031
# K=5, Silhouette Score=0.12201271090648004
# K=6, Silhouette Score=0.11931697913936086
# K=7, Silhouette Score=0.12100212789597503
# K=8, Silhouette Score=0.1260274483639975
# K=9, Silhouette Score=0.12306605172724668

# %% [markdown]
# # Apply K-Means

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
data["Cluster"] = kmeans.fit_predict(df_scaled)
data.head()
# Out:
#    Age  Gender  ContractType  MonthlyCharges   TotalSpent  DevicesConnected  \
# 0   56       1             1       96.028982  1249.110874                 4
# 1   69       0             2       33.710971  1570.074519                 1
# 2   46       1             2       73.531013  1790.270343                 4
# 3   32       0             1       41.520187   492.452904                 2
# 4   60       1             2       21.212077   594.571244                 2
#
#    SupportCalls  Cluster
# 0             5        3
# 1             7        1
# 2             9        3
# 3             0        1
# 4             3        2

# %% [markdown]
# # PCA for Visualization

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(df_scaled)

data["PCA1"] = pca_data[:, 0]
data["PCA2"] = pca_data[:, 1]

# %% [markdown]
# # Scatter Plot of Clusters

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=data["PCA1"], y=data["PCA2"], hue=data["Cluster"], palette="tab10")
plt.title("Customer Segmentation Clusters")
plt.show()

# %%
import seaborn as sns

cluster_counts = pd.Series(kmeans.labels_).value_counts()

plt.figure(figsize=(6,4))
sns.barplot(x=cluster_counts.index, y=cluster_counts.values)
plt.xlabel("Cluster")
plt.ylabel("Number of Customers")
plt.title("Customer Count per Cluster")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

pca3 = PCA(n_components=3)
pca3_data = pca3.fit_transform(data)

fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pca3_data[:,0], pca3_data[:,1], pca3_data[:,2], c=kmeans.labels_)
ax.set_title("Customer Clusters (PCA 3D)")
plt.show()
